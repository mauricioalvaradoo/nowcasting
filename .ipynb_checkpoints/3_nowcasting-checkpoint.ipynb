# %% [markdown]
# # Nowcasting with Mixed Monthly/Quarterly data
# Quarterly GDP forecast with monthly data. It is inspired by a script of [Chan Fulton](https://www.chadfulton.com/topics/statespace_large_dynamic_factor_models.html).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
import statsmodels.tsa.api as tsa

import warnings
warnings.simplefilter('ignore')

# %%
codes = pd.read_excel('series.xlsx', sheet_name='Series')

dta = {
    '2023-05': pd.read_pickle('Data/monthly/data_st_2023_05.pkl'),
    '2023-06': pd.read_pickle('Data/monthly/data_st_2023_06.pkl'),
    '2023-07': pd.read_pickle('Data/monthly/data_st_2023_07.pkl'),
    '2023-08': pd.read_pickle('Data/monthly/data_st_2023_08.pkl'),
    # '2023-09': pd.read_pickle('Data/monthly/data_st_2023_09.pkl'),
}
dta_gdp = {
    '2023-05': pd.read_pickle('Data/quarterly/gdp_st_2023_05.pkl'),
    '2023-06': pd.read_pickle('Data/quarterly/gdp_st_2023_06.pkl'),
    '2023-07': pd.read_pickle('Data/quarterly/gdp_st_2023_07.pkl'),
    '2023-08': pd.read_pickle('Data/quarterly/gdp_st_2023_08.pkl'),
    # '2023-09': pd.read_pickle('Data/quarterly/gdp_st_2023_09.pkl'),
}

# %%
# Declarations -> Current month
df_m  = dta['2023-08']
df_q  = dta_gdp['2023-08']

# Edit
df_q = pd.DataFrame( df_q['2015Q2':] )

codes.head()
# Out:
#     Group       Code                 Description Source          Measure  \
# 0  Output  PN01756AM          Producto: Agrícola   BCRP  Índice 2007=100
# 1  Output  PN01757AM          Producto: Pecuario   BCRP  Índice 2007=100
# 2  Output  PN01758AM             Producto: Pesca   BCRP  Índice 2007=100
# 3  Output  PN01760AM  Producto: Minería Metálica   BCRP  Índice 2007=100
# 4  Output  PN01761AM     Producto: Hidrocarburos   BCRP  Índice 2007=100
#
#   Frequency Tcode
# 0   Mensual    4+
# 1   Mensual    4+
# 2   Mensual    4+
# 3   Mensual    4+
# 4   Mensual    4+

# %%
df_m.tail()
# Out:
#          Producto: Agrícola  Producto: Pecuario  Producto: Pesca  \
# 2023-04           -2.131880           -1.352394        -2.122214
# 2023-05           -2.190818           -1.374609        -2.327959
# 2023-06           -2.247333           -1.392021        -2.578958
# 2023-07                 NaN                 NaN              NaN
# 2023-08                 NaN                 NaN              NaN
#
#          Producto: Minería Metálica  Producto: Hidrocarburos  \
# 2023-04                    0.659620                 0.141804
# 2023-05                    0.668583                 0.179253
# 2023-06                    0.677958                 0.210948
# 2023-07                         NaN                      NaN
# 2023-08                         NaN                      NaN
#
#          Producto: Manufactura Procesadores Recursos Primarios  \
# 2023-04                                          -0.917826
# 2023-05                                          -0.986408
# 2023-06                                          -1.073445
# 2023-07                                                NaN
# 2023-08                                                NaN
#
#          Producto: Manufactura no Primaria  Producto: Electricidad y Agua  \
# 2023-04                          -0.955002                       0.239983
# 2023-05                          -0.973054                       0.236754
# 2023-06                          -0.989449                       0.232746
# 2023-07                                NaN                            NaN
# 2023-08                                NaN                            NaN
#
#          Producto: Construcción  Producto: Comercio  ...  \
# 2023-04               -0.743101            0.008786  ...
# 2023-05               -0.761774            0.010542  ...
# 2023-06               -0.777246            0.011720  ...
# 2023-07                     NaN                 NaN  ...
# 2023-08                     NaN                 NaN  ...
#
#          6-Month Treasury Bill  1-Year Treasury Rate  5-Year Treasury Rate  \
# 2023-04               2.320253              2.150874              1.602350
# 2023-05               2.483818              2.307125              1.651162
# 2023-06               2.592862              2.531312              2.002609
# 2023-07               2.647383              2.619628              2.188095
# 2023-08               2.654199              2.619628              2.354056
#
#          10-Year Treasury Rate  Indice de Dólar   S&P 500  \
# 2023-04               1.505318        -1.374865  0.827440
# 2023-05               1.637532         0.546940 -0.045624
# 2023-06               1.853882         0.201387  1.077585
# 2023-07               2.034173        -1.238258  0.798711
# 2023-08               2.358698         1.078485 -0.533964
#
#          Dow Jones Industrial Average  NASDAQ Composite  FTSE 100  Nikkei 225
# 2023-04                      0.836527          0.596075  0.649844    0.350491
# 2023-05                     -0.513442          0.451737 -0.469112    1.376003
# 2023-06                      0.291929          1.540487 -0.573346    1.822480
# 2023-07                      0.504985          0.700196 -0.195010   -0.186575
# 2023-08                     -0.094328         -0.730692 -0.269973   -0.543662
#
# [5 rows x 129 columns]

# %%
# Adding GDP Growth -> Monthly variable which will be generated
codes = codes.append(
    {
        'Description': 'GDP Growth',
        'Group': 'Output'
    },
    ignore_index=True
)


# Groups!
codes[['Group', 'Description']].groupby('Group', sort=False).count()
# Out:
#                   Description
# Group
# Output                     13
# Labor Market               21
# Juncture                   14
# Prices                     13
# Government                 11
# Balance of Trade           17
# Finance                    24
# Stock Market                6
# Quotes                     11

# %%
# Assignment of groups and a `Global` one
factors = {row['Description']: ['Global', row['Group']] for ix, row in codes.iterrows()}

# Amount of factor per groups
factor_multiplicities = {
    'Global': 2,
    'Output': 1,
    'Labor Market': 1,
    'Juncture': 1,
    'Prices': 1,
    'Government': 1,
    'Balance of Trade': 1,
    'Finance': 1,
    'Stock Market': 1,
    'Quotes': 1
}

# AR(p) order of idiosyncratic disturbances
factor_orders = {
    ('Output', 'Labor Market', 'Juncture', 'Prices', 'Government',
     'Balance of Trade', 'Finance', 'Stock Market', 'Quotes'): 2,
    'Global': 1
}

# %%
factors
# Out:
# {'Producto: Agrícola': ['Global', 'Output'],
#  'Producto: Pecuario': ['Global', 'Output'],
#  'Producto: Pesca': ['Global', 'Output'],
#  'Producto: Minería Metálica': ['Global', 'Output'],
#  'Producto: Hidrocarburos': ['Global', 'Output'],
#  'Producto: Manufactura Procesadores Recursos Primarios': ['Global', 'Output'],
#  'Producto: Manufactura no Primaria': ['Global', 'Output'],
#  'Producto: Electricidad y Agua': ['Global', 'Output'],
#  'Producto: Construcción': ['Global', 'Output'],
#  'Producto: Comercio': ['Global', 'Output'],
#  'Producto: Otros Servicios': ['Global', 'Output'],
#  'Producto: Derechos de Importación y otros Impuestos': ['Global', 'Output'],
#  'PEA Ocupada - Por Edad - 14 a 24 años': ['Global', 'Labor Market'],
#  'PEA Ocupada - Por Edad - 25 a 44 años': ['Global', 'Labor Market'],
#  'PEA Ocupada - Por Edad - 45 a más años': ['Global', 'Labor Market'],
#  'PEA Ocupada - Por Categoría Ocupacional - Independiente': ['Global',
#   'Labor Market'],
#  'PEA Ocupada - Por Categoría Ocupacional - Dependiente': ['Global',
#   'Labor Market'],
#  'PEA Ocupada - Por Categoría Ocupacional - Trabajador no Remunerado': ['Global',
#   'Labor Market'],
#  'PEA Ocupada - Por Tamaño de Empresa - De 1 a 10 trabajadores': ['Global',
#   'Labor Market'],
#  'PEA Ocupada - Por Tamaño de Empresa - De 11 a 50 trabajadores': ['Global',
#   'Labor Market'],
#  'PEA Ocupada - Por Tamaño de Empresa - De 51 y más': ['Global',
#   'Labor Market'],
#  'PEA Adecuadamente Empleada': ['Global', 'Labor Market'],
#  'PEA Subempleada': ['Global', 'Labor Market'],
#  'Coeficiente de Ocupación': ['Global', 'Labor Market'],
#  'Tasa de Desempleo (%) - Por Género - Hombre': ['Global', 'Labor Market'],
#  'Tasa de Desempleo (%) - Por Género - Mujer': ['Global', 'Labor Market'],
#  'Tasa de Desempleo (%) - Por Grupos de Edad - 14 a 24 años': ['Global',
#   'Labor Market'],
#  'Tasa de Desempleo (%) - Por Grupos de Edad - 25 a 44 años': ['Global',
#   'Labor Market'],
#  'Tasa de Desempleo (%) - Por Grupos de Edad - 45 a más años': ['Global',
#   'Labor Market'],
#  'Ingreso Mensual': ['Global', 'Labor Market'],
#  'Remuneración Mínima Vital': ['Global', 'Labor Market'],
#  'Ingreso promedio del sector formal privado': ['Global', 'Labor Market'],
#  'Masa salarial del sector formal total': ['Global', 'Labor Market'],
#  'Índice de venta respecto al mes anterior': ['Global', 'Juncture'],
#  'Índice de inventarios respecto al mes anterior': ['Global', 'Juncture'],
#  'Índice de órdenes de compra respecto al mes anterior': ['Global',
#   'Juncture'],
#  'Índice de la situación actual del negocio': ['Global', 'Juncture'],
#  'Índice de expectativas de la economía a 3 meses': ['Global', 'Juncture'],
#  'Índice de expectativas del sector a 3 meses': ['Global', 'Juncture'],
#  'Índice de expectativas de la demanda a 3 meses': ['Global', 'Juncture'],
#  'Índice de expectativas de la economía a 12 meses': ['Global', 'Juncture'],
#  'Índice de expectativas de demanda por sus productos a 12 meses': ['Global',
#   'Juncture'],
#  'Índice de expectativas del sector a 12 meses': ['Global', 'Juncture'],
#  'Consumo Interno de Electricidad': ['Global', 'Juncture'],
#  'Consumo Interno de Electricidad sin Minería': ['Global', 'Juncture'],
#  'Producto EEUU: Manufactura': ['Global', 'Juncture'],
#  'Indice de Dólar': ['Global', 'Juncture'],
#  'IPC Sin Alimentos': ['Global', 'Prices'],
#  'IPC Sin Alimentos y Energía': ['Global', 'Prices'],
#  'IPC Alimentos y Energía': ['Global', 'Prices'],
#  'IPC Subyacente': ['Global', 'Prices'],
#  'IPC No Subyacente': ['Global', 'Prices'],
#  'IPC Transables': ['Global', 'Prices'],
#  'IPC No Transables': ['Global', 'Prices'],
#  'IPC No Transables Sin Alimentos': ['Global', 'Prices'],
#  'IPC Alimentos y Bebidas': ['Global', 'Prices'],
#  'IPC Sin Alimentos y Bebidas': ['Global', 'Prices'],
#  'IPC Subyacente Sin Alimentos y Bebidas': ['Global', 'Prices'],
#  'IPC Importado': ['Global', 'Prices'],
#  'Índice de Precios al por Mayor': ['Global', 'Prices'],
#  'Ingresos del Gobierno Central - Impuesto a las importaciones': ['Global',
#   'Government'],
#  'Ingresos del Gobierno Central - Impuesto General a las Ventas': ['Global',
#   'Government'],
#  'Ingresos del Gobierno Central - Impuesto Selectivo al Consumo': ['Global',
#   'Government'],
#  'Ingresos del Gobierno Central - Otros ingresos': ['Global', 'Government'],
#  'Ingresos del Gobierno Central - Ingresos no tributarios': ['Global',
#   'Government'],
#  'Gastos del Gobierno Central - Remuneraciones': ['Global', 'Government'],
#  'Gastos del Gobierno Central - Bienes y servicios': ['Global', 'Government'],
#  'Gastos del Gobierno Central - Transferencias': ['Global', 'Government'],
#  'Gastos del Gobierno Central - Formación bruta de capital': ['Global',
#   'Government'],
#  'Gastos del Gobierno Central - Intereses de la deuda interna': ['Global',
#   'Government'],
#  'Gastos del Gobierno Central - Intereses de la deuda externa': ['Global',
#   'Government'],
#  'Exportaciones de Productos Tradicionales - Pesqueros': ['Global',
#   'Balance of Trade'],
#  'Exportaciones de Productos Tradicionales - Agrícolas': ['Global',
#   'Balance of Trade'],
#  'Exportaciones de Productos Tradicionales - Mineros': ['Global',
#   'Balance of Trade'],
#  'Exportaciones de Productos Tradicionales - Petróleo y Gas Natural': ['Global',
#   'Balance of Trade'],
#  'Exportaciones de Productos no Tradicionales - Agropecuarios': ['Global',
#   'Balance of Trade'],
#  'Exportaciones de Productos no Tradicionales - Pesqueros': ['Global',
#   'Balance of Trade'],
#  'Exportaciones de Productos no Tradicionales - Textiles': ['Global',
#   'Balance of Trade'],
#  'Exportaciones de Productos no Tradicionales - Maderas y Papeles, y sus Manufacturas': ['Global',
#   'Balance of Trade'],
#  'Exportaciones de Productos no Tradicionales - Químicos': ['Global',
#   'Balance of Trade'],
#  'Exportaciones de Productos no Tradicionales - Minerales no Metálicos': ['Global',
#   'Balance of Trade'],
#  'Exportaciones de Productos no Tradicionales - Sidero - Metalúrgicos y Joyería': ['Global',
#   'Balance of Trade'],
#  'Exportaciones de Productos no Tradicionales - Metal - Mecánicos': ['Global',
#   'Balance of Trade'],
#  'Importaciones de Bienes de Consumo': ['Global', 'Balance of Trade'],
#  'Importaciones de Insumos': ['Global', 'Balance of Trade'],
#  'Importaciones de Bienes de Capital': ['Global', 'Balance of Trade'],
#  'Índice de Precios Nominales - Exportaciones': ['Global', 'Balance of Trade'],
#  'Índice de Precios Nominales - Importaciones': ['Global', 'Balance of Trade'],
#  'Tasa de Referencia de la Política Monetaria': ['Global', 'Finance'],
#  'Tasa de Encaje': ['Global', 'Finance'],
#  'Tasa de los Créditos de Regulación Monetaria en MN': ['Global', 'Finance'],
#  'Tasa de los Depósitos Overnight en MN': ['Global', 'Finance'],
#  'Rendimiento del Bono del gobierno peruano a 10 años': ['Global', 'Finance'],
#  'Reservas Internacionales Netas': ['Global', 'Finance'],
#  'Dolarización del Crédito del sistema bancario al sector privado': ['Global',
#   'Finance'],
#  'Dolarización del Crédito de las sociedades creadoras de depósito al sector privado': ['Global',
#   'Finance'],
#  'Dolarización de la Liquidez del sistema bancario': ['Global', 'Finance'],
#  'Dolarización de la Liquidez del sistema financiero': ['Global', 'Finance'],
#  'Valor del Fondo SPP': ['Global', 'Finance'],
#  'Tipo de cambio U.S.': ['Global', 'Finance'],
#  'Tipo de cambio Euro': ['Global', 'Finance'],
#  'Tipo de cambio Yuan': ['Global', 'Finance'],
#  'Emisión primaria por el BCRP': ['Global', 'Finance'],
#  'Circulante': ['Global', 'Finance'],
#  'Multiplicador monetario': ['Global', 'Finance'],
#  'Prima de riesgo - EMBIG': ['Global', 'Finance'],
#  'Effective Federal Funds Rate': ['Global', 'Finance'],
#  '3-Month Treasury Bill': ['Global', 'Finance'],
#  '6-Month Treasury Bill': ['Global', 'Finance'],
#  '1-Year Treasury Rate': ['Global', 'Finance'],
#  '5-Year Treasury Rate': ['Global', 'Finance'],
#  '10-Year Treasury Rate': ['Global', 'Finance'],
#  'Índice General de S&P/BVL': ['Global', 'Stock Market'],
#  'S&P 500': ['Global', 'Stock Market'],
#  'Dow Jones Industrial Average': ['Global', 'Stock Market'],
#  'NASDAQ Composite': ['Global', 'Stock Market'],
#  'FTSE 100': ['Global', 'Stock Market'],
#  'Nikkei 225': ['Global', 'Stock Market'],
#  'Cobre LME': ['Global', 'Quotes'],
#  'Oro LME': ['Global', 'Quotes'],
#  'Plata H. Harman': ['Global', 'Quotes'],
#  'Zinc LME': ['Global', 'Quotes'],
#  'Estaño LME': ['Global', 'Quotes'],
#  'Plomo LME': ['Global', 'Quotes'],
#  'Petróleo WTI': ['Global', 'Quotes'],
#  'Trigo EEUU': ['Global', 'Quotes'],
#  'Maíz EEUU': ['Global', 'Quotes'],
#  'Aceite Soya EEUU': ['Global', 'Quotes'],
#  'Harina de Pescado Hamburgo': ['Global', 'Quotes'],
#  'GDP Growth': ['Global', 'Output']}

# %%
factor_multiplicities
# Out:
# {'Global': 2,
#  'Output': 1,
#  'Labor Market': 1,
#  'Juncture': 1,
#  'Prices': 1,
#  'Government': 1,
#  'Balance of Trade': 1,
#  'Finance': 1,
#  'Stock Market': 1,
#  'Quotes': 1}

# %%
factor_orders
# Out:
# {('Output',
#   'Labor Market',
#   'Juncture',
#   'Prices',
#   'Government',
#   'Balance of Trade',
#   'Finance',
#   'Stock Market',
#   'Quotes'): 2,
#  'Global': 1}

# %% [markdown]
# ## Dynamic Factor MQ model

# %%
# Declaration
model = tsa.DynamicFactorMQ(
    endog = df_m,
    endog_quarterly = df_q['GDP Growth'],
    factors = factors,
    factor_orders = factor_orders,
    factor_multiplicities = factor_multiplicities
)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                          Model Specification: Dynamic Factor Model
# ============================================================================================
# Model:                 Dynamic Factor Model   # of monthly variables:                    129
#                    + 11 factors in 2 blocks   # of quarterly variables:                    1
#                     + Mixed frequency (M/Q)   # of factor blocks:                          2
#                       + AR(1) idiosyncratic   Idiosyncratic disturbances:              AR(1)
# Sample:                             2015-01   Standardize variables:                    True
#                                   - 2023-08
#                                                                Observed variables / factor loadings
# ==================================================================================================================================================================
#               Dep. variable     Output Labor Market   Juncture      Prices  Government Balance of Trade    Finance Stock Market     Quotes    Global.1    Global.2
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------
#          Producto: Agrícola       X                                                                                                              X           X
#          Producto: Pecuario       X                                                                                                              X           X
#             Producto: Pesca       X                                                                                                              X           X
# Producto: Minería Metáli...       X                                                                                                              X           X
#     Producto: Hidrocarburos       X                                                                                                              X           X
# Producto: Manufactura Pr...       X                                                                                                              X           X
# Producto: Manufactura no...       X                                                                                                              X           X
# Producto: Electricidad y...       X                                                                                                              X           X
#      Producto: Construcción       X                                                                                                              X           X
#          Producto: Comercio       X                                                                                                              X           X
# Producto: Otros Servicio...       X                                                                                                              X           X
# Producto: Derechos de Im...       X                                                                                                              X           X
# PEA Ocupada - Por Edad -...                 X                                                                                                    X           X
# PEA Ocupada - Por Edad -...                 X                                                                                                    X           X
# PEA Ocupada - Por Edad -...                 X                                                                                                    X           X
# PEA Ocupada - Por Catego...                 X                                                                                                    X           X
# PEA Ocupada - Por Catego...                 X                                                                                                    X           X
# PEA Ocupada - Por Catego...                 X                                                                                                    X           X
# PEA Ocupada - Por Tamaño...                 X                                                                                                    X           X
# PEA Ocupada - Por Tamaño...                 X                                                                                                    X           X
# PEA Ocupada - Por Tamaño...                 X                                                                                                    X           X
# PEA Adecuadamente Emplea...                 X                                                                                                    X           X
#             PEA Subempleada                 X                                                                                                    X           X
#    Coeficiente de Ocupación                 X                                                                                                    X           X
# Tasa de Desempleo (%) - ...                 X                                                                                                    X           X
# Tasa de Desempleo (%) - ...                 X                                                                                                    X           X
# Tasa de Desempleo (%) - ...                 X                                                                                                    X           X
# Tasa de Desempleo (%) - ...                 X                                                                                                    X           X
# Tasa de Desempleo (%) - ...                 X                                                                                                    X           X
#             Ingreso Mensual                 X                                                                                                    X           X
# Remuneración Mínima Vita...                 X                                                                                                    X           X
# Ingreso promedio del sec...                 X                                                                                                    X           X
# Masa salarial del sector...                 X                                                                                                    X           X
# Índice de venta respecto...                              X                                                                                       X           X
# Índice de inventarios re...                              X                                                                                       X           X
# Índice de órdenes de com...                              X                                                                                       X           X
# Índice de la situación a...                              X                                                                                       X           X
# Índice de expectativas d...                              X                                                                                       X           X
# Índice de expectativas d...                              X                                                                                       X           X
# Índice de expectativas d...                              X                                                                                       X           X
# Índice de expectativas d...                              X                                                                                       X           X
# Índice de expectativas d...                              X                                                                                       X           X
# Índice de expectativas d...                              X                                                                                       X           X
# Consumo Interno de Elect...                              X                                                                                       X           X
# Consumo Interno de Elect...                              X                                                                                       X           X
#           IPC Sin Alimentos                                           X                                                                          X           X
# IPC Sin Alimentos y Ener...                                           X                                                                          X           X
#     IPC Alimentos y Energía                                           X                                                                          X           X
#              IPC Subyacente                                           X                                                                          X           X
#           IPC No Subyacente                                           X                                                                          X           X
#              IPC Transables                                           X                                                                          X           X
#           IPC No Transables                                           X                                                                          X           X
# IPC No Transables Sin Al...                                           X                                                                          X           X
#     IPC Alimentos y Bebidas                                           X                                                                          X           X
# IPC Sin Alimentos y Bebi...                                           X                                                                          X           X
# IPC Subyacente Sin Alime...                                           X                                                                          X           X
#               IPC Importado                                           X                                                                          X           X
# Índice de Precios al por...                                           X                                                                          X           X
# Ingresos del Gobierno Ce...                                                     X                                                                X           X
# Ingresos del Gobierno Ce...                                                     X                                                                X           X
# Ingresos del Gobierno Ce...                                                     X                                                                X           X
# Ingresos del Gobierno Ce...                                                     X                                                                X           X
# Ingresos del Gobierno Ce...                                                     X                                                                X           X
# Gastos del Gobierno Cent...                                                     X                                                                X           X
# Gastos del Gobierno Cent...                                                     X                                                                X           X
# Gastos del Gobierno Cent...                                                     X                                                                X           X
# Gastos del Gobierno Cent...                                                     X                                                                X           X
# Gastos del Gobierno Cent...                                                     X                                                                X           X
# Gastos del Gobierno Cent...                                                     X                                                                X           X
# Exportaciones de Product...                                                                   X                                                  X           X
# Exportaciones de Product...                                                                   X                                                  X           X
# Exportaciones de Product...                                                                   X                                                  X           X
# Exportaciones de Product...                                                                   X                                                  X           X
# Exportaciones de Product...                                                                   X                                                  X           X
# Exportaciones de Product...                                                                   X                                                  X           X
# Exportaciones de Product...                                                                   X                                                  X           X
# Exportaciones de Product...                                                                   X                                                  X           X
# Exportaciones de Product...                                                                   X                                                  X           X
# Exportaciones de Product...                                                                   X                                                  X           X
# Exportaciones de Product...                                                                   X                                                  X           X
# Exportaciones de Product...                                                                   X                                                  X           X
# Importaciones de Bienes ...                                                                   X                                                  X           X
#    Importaciones de Insumos                                                                   X                                                  X           X
# Importaciones de Bienes ...                                                                   X                                                  X           X
# Índice de Precios Nomina...                                                                   X                                                  X           X
# Índice de Precios Nomina...                                                                   X                                                  X           X
# Tasa de Referencia de la...                                                                                   X                                  X           X
#              Tasa de Encaje                                                                                   X                                  X           X
# Tasa de los Créditos de ...                                                                                   X                                  X           X
# Tasa de los Depósitos Ov...                                                                                   X                                  X           X
# Rendimiento del Bono del...                                                                                   X                                  X           X
# Reservas Internacionales...                                                                                   X                                  X           X
# Dolarización del Crédito...                                                                                   X                                  X           X
# Dolarización del Crédito...                                                                                   X                                  X           X
# Dolarización de la Liqui...                                                                                   X                                  X           X
# Dolarización de la Liqui...                                                                                   X                                  X           X
#         Valor del Fondo SPP                                                                                   X                                  X           X
#         Tipo de cambio U.S.                                                                                   X                                  X           X
#         Tipo de cambio Euro                                                                                   X                                  X           X
#         Tipo de cambio Yuan                                                                                   X                                  X           X
# Emisión primaria por el ...                                                                                   X                                  X           X
#                  Circulante                                                                                   X                                  X           X
#     Multiplicador monetario                                                                                   X                                  X           X
#     Prima de riesgo - EMBIG                                                                                   X                                  X           X
# Índice General de S&P/BV...                                                                                             X                        X           X
#                   Cobre LME                                                                                                           X          X           X
#                     Oro LME                                                                                                           X          X           X
#             Plata H. Harman                                                                                                           X          X           X
#                    Zinc LME                                                                                                           X          X           X
#                  Estaño LME                                                                                                           X          X           X
#                   Plomo LME                                                                                                           X          X           X
#                Petróleo WTI                                                                                                           X          X           X
#                  Trigo EEUU                                                                                                           X          X           X
#                   Maíz EEUU                                                                                                           X          X           X
#            Aceite Soya EEUU                                                                                                           X          X           X
# Harina de Pescado Hambur...                                                                                                           X          X           X
# Producto EEUU: Manufactu...                              X                                                                                       X           X
# Effective Federal Funds ...                                                                                   X                                  X           X
#       3-Month Treasury Bill                                                                                   X                                  X           X
#       6-Month Treasury Bill                                                                                   X                                  X           X
#        1-Year Treasury Rate                                                                                   X                                  X           X
#        5-Year Treasury Rate                                                                                   X                                  X           X
#       10-Year Treasury Rate                                                                                   X                                  X           X
#             Indice de Dólar                              X                                                                                       X           X
#                     S&P 500                                                                                             X                        X           X
# Dow Jones Industrial Ave...                                                                                             X                        X           X
#            NASDAQ Composite                                                                                             X                        X           X
#                    FTSE 100                                                                                             X                        X           X
#                  Nikkei 225                                                                                             X                        X           X
#                  GDP Growth       X                                                                                                              X           X
#                                                 Factor blocks:
# ==============================================================================================================
#                                                                                               block      order
# --------------------------------------------------------------------------------------------------------------
# Output, Labor Market, Juncture, Prices, Government, Balance of Trade, Finance, Stock Market, Quotes          2
#                                                                                  Global.1, Global.2          1
# ==============================================================================================================
# """

# %%
# Coefficients estimated
results = model.fit(disp=10)
results.summary()
# Out:
# EM start iterations, llf=-6197.3
# EM iteration 10, llf=-2922, convergence criterion=0.0094426
# EM iteration 20, llf=-2587.7, convergence criterion=0.014136
# EM iteration 30, llf=-2223.6, convergence criterion=0.016135
# EM iteration 40, llf=-1863.3, convergence criterion=0.019112
# EM terminated at iteration 46, llf=-1618.6, convergence criterion=0.041005 (while specified tolerance was 1e-06)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                     Dynamic Factor Results
# ==============================================================================================
# Dep. Variable:     "Producto: Agrícola", and 129 more   No. Observations:                  104
# Model:                           Dynamic Factor Model   Log Likelihood               -1790.075
#                              + 11 factors in 2 blocks   AIC                           5308.151
#                               + Mixed frequency (M/Q)   BIC                           7592.905
#                                 + AR(1) idiosyncratic   HQIC                          6233.772
# Date:                                Wed, 20 Sep 2023   EM Iterations                       46
# Time:                                        13:43:22
# Sample:                                    01-31-2015
#                                          - 08-31-2023
# Covariance Type:                         Not computed
#                                                                                         Observation equation:
# =====================================================================================================================================================================================================
#            Factor loadings:     Output Labor Market   Juncture      Prices  Government Balance of Trade    Finance Stock Market     Quotes    Global.1    Global.2    idiosyncratic: AR(1)       var.
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#          Producto: Agrícola      -0.26            .          .           .           .                .          .            .          .        0.02       -0.17                    0.95       0.04
#          Producto: Pecuario      -0.38            .          .           .           .                .          .            .          .       -0.13       -0.16                    0.93       0.01
#             Producto: Pesca      -0.19            .          .           .           .                .          .            .          .        0.08       -0.16                    0.94       0.06
# Producto: Minería Metáli...      -0.16            .          .           .           .                .          .            .          .       -0.08        0.12                    0.96       0.00
#     Producto: Hidrocarburos      -0.18            .          .           .           .                .          .            .          .       -0.10       -0.05                    0.95       0.04
# Producto: Manufactura Pr...      -0.18            .          .           .           .                .          .            .          .        0.06       -0.07                    0.94       0.09
# Producto: Manufactura no...      -0.36            .          .           .           .                .          .            .          .        0.07       -0.00                    0.95       0.00
# Producto: Electricidad y...      -0.30            .          .           .           .                .          .            .          .       -0.06        0.08                    0.95       0.00
#      Producto: Construcción      -0.28            .          .           .           .                .          .            .          .        0.11        0.02                    0.95       0.01
#          Producto: Comercio      -0.33            .          .           .           .                .          .            .          .        0.01        0.06                    0.97       0.00
# Producto: Otros Servicio...      -0.40            .          .           .           .                .          .            .          .       -0.06       -0.00                    0.94       0.00
# Producto: Derechos de Im...      -0.38            .          .           .           .                .          .            .          .        0.03        0.01                    0.97       0.00
# PEA Ocupada - Por Edad -...          .        -0.30          .           .           .                .          .            .          .       -0.02       -0.02                    0.13       0.17
# PEA Ocupada - Por Edad -...          .        -0.31          .           .           .                .          .            .          .       -0.02       -0.02                    0.51       0.02
# PEA Ocupada - Por Edad -...          .        -0.31          .           .           .                .          .            .          .       -0.03       -0.02                    0.13       0.03
# PEA Ocupada - Por Catego...          .        -0.31          .           .           .                .          .            .          .       -0.01       -0.02                   -0.09       0.05
# PEA Ocupada - Por Catego...          .        -0.31          .           .           .                .          .            .          .       -0.04       -0.02                   -0.00       0.06
# PEA Ocupada - Por Catego...          .        -0.24          .           .           .                .          .            .          .        0.03       -0.02                    0.03       0.47
# PEA Ocupada - Por Tamaño...          .        -0.31          .           .           .                .          .            .          .       -0.01       -0.02                   -0.36       0.02
# PEA Ocupada - Por Tamaño...          .        -0.27          .           .           .                .          .            .          .       -0.04       -0.00                    0.07       0.30
# PEA Ocupada - Por Tamaño...          .        -0.25          .           .           .                .          .            .          .       -0.06       -0.02                   -0.13       0.31
# PEA Adecuadamente Emplea...          .        -0.30          .           .           .                .          .            .          .       -0.05       -0.01                    0.36       0.09
#             PEA Subempleada          .        -0.29          .           .           .                .          .            .          .        0.02       -0.03                    0.28       0.16
#    Coeficiente de Ocupación          .        -0.04          .           .           .                .          .            .          .       -0.20       -0.08                    0.78       0.10
# Tasa de Desempleo (%) - ...          .        -0.05          .           .           .                .          .            .          .        0.20        0.09                    0.67       0.08
# Tasa de Desempleo (%) - ...          .        -0.07          .           .           .                .          .            .          .        0.17        0.11                    0.75       0.11
# Tasa de Desempleo (%) - ...          .        -0.07          .           .           .                .          .            .          .        0.20        0.07                    0.62       0.12
# Tasa de Desempleo (%) - ...          .        -0.04          .           .           .                .          .            .          .        0.19        0.11                    0.71       0.09
# Tasa de Desempleo (%) - ...          .        -0.07          .           .           .                .          .            .          .        0.15        0.14                    0.77       0.07
#             Ingreso Mensual          .         0.05          .           .           .                .          .            .          .       -0.06       -0.05                    0.99       0.09
# Remuneración Mínima Vita...          .        -0.00          .           .           .                .          .            .          .       -0.03        0.00                   -0.04       0.98
# Ingreso promedio del sec...          .        -0.08          .           .           .                .          .            .          .        0.02        0.12                    0.95       0.09
# Masa salarial del sector...          .        -0.07          .           .           .                .          .            .          .       -0.05        0.11                    0.95       0.07
# Índice de venta respecto...          .            .      -0.24           .           .                .          .            .          .        0.10        0.17                    0.86       0.08
# Índice de inventarios re...          .            .       0.20           .           .                .          .            .          .        0.11       -0.11                    0.40       0.31
# Índice de órdenes de com...          .            .      -0.32           .           .                .          .            .          .       -0.02       -0.01                    0.67       0.14
# Índice de la situación a...          .            .      -0.21           .           .                .          .            .          .       -0.13       -0.04                    0.79       0.05
# Índice de expectativas d...          .            .      -0.35           .           .                .          .            .          .        0.01       -0.03                    0.45       0.03
# Índice de expectativas d...          .            .      -0.34           .           .                .          .            .          .       -0.02       -0.02                    0.71       0.02
# Índice de expectativas d...          .            .      -0.33           .           .                .          .            .          .       -0.03       -0.01                    0.64       0.06
# Índice de expectativas d...          .            .      -0.34           .           .                .          .            .          .        0.08       -0.03                    0.70       0.03
# Índice de expectativas d...          .            .      -0.34           .           .                .          .            .          .        0.03       -0.04                    0.22       0.02
# Índice de expectativas d...          .            .      -0.36           .           .                .          .            .          .        0.07       -0.02                    0.21       0.02
# Consumo Interno de Elect...          .            .      -0.17           .           .                .          .            .          .        0.00        0.22                    0.92       0.04
# Consumo Interno de Elect...          .            .      -0.20           .           .                .          .            .          .        0.06        0.22                    0.88       0.05
#           IPC Sin Alimentos          .            .          .       -0.34           .                .          .            .          .        0.01       -0.03                    0.89       0.00
# IPC Sin Alimentos y Ener...          .            .          .       -0.31           .                .          .            .          .       -0.01       -0.02                    0.22       0.20
#     IPC Alimentos y Energía          .            .          .       -0.28           .                .          .            .          .        0.01        0.03                   -0.15       0.69
#              IPC Subyacente          .            .          .       -0.25           .                .          .            .          .       -0.06        0.04                    0.35       0.31
#           IPC No Subyacente          .            .          .       -0.31           .                .          .            .          .        0.03       -0.01                   -0.13       0.63
#              IPC Transables          .            .          .       -0.19           .                .          .            .          .       -0.02        0.07                    0.45       0.48
#           IPC No Transables          .            .          .       -0.32           .                .          .            .          .        0.01       -0.01                   -0.09       0.53
# IPC No Transables Sin Al...          .            .          .       -0.32           .                .          .            .          .        0.01       -0.05                    0.28       0.14
#     IPC Alimentos y Bebidas          .            .          .       -0.25           .                .          .            .          .       -0.00        0.04                   -0.06       0.82
# IPC Sin Alimentos y Bebi...          .            .          .       -0.34           .                .          .            .          .        0.01       -0.03                    0.89       0.00
# IPC Subyacente Sin Alime...          .            .          .       -0.27           .                .          .            .          .       -0.02       -0.02                    0.32       0.44
#               IPC Importado          .            .          .       -0.18           .                .          .            .          .        0.02        0.02                    0.38       0.61
# Índice de Precios al por...          .            .          .       -0.16           .                .          .            .          .        0.02        0.04                    0.26       0.75
# Ingresos del Gobierno Ce...          .            .          .           .       -0.44                .          .            .          .       -0.02       -0.07                    0.97       0.01
# Ingresos del Gobierno Ce...          .            .          .           .       -0.45                .          .            .          .        0.02       -0.06                    0.94       0.00
# Ingresos del Gobierno Ce...          .            .          .           .       -0.36                .          .            .          .       -0.03       -0.01                    0.98       0.03
# Ingresos del Gobierno Ce...          .            .          .           .       -0.42                .          .            .          .        0.01       -0.06                    0.96       0.02
# Ingresos del Gobierno Ce...          .            .          .           .       -0.38                .          .            .          .       -0.00       -0.06                    0.93       0.04
# Gastos del Gobierno Cent...          .            .          .           .        0.29                .          .            .          .       -0.00        0.11                    0.95       0.06
# Gastos del Gobierno Cent...          .            .          .           .       -0.20                .          .            .          .        0.09        0.00                    0.95       0.04
# Gastos del Gobierno Cent...          .            .          .           .        0.25                .          .            .          .        0.15       -0.07                    0.95       0.02
# Gastos del Gobierno Cent...          .            .          .           .       -0.18                .          .            .          .        0.07        0.09                    0.96       0.02
# Gastos del Gobierno Cent...          .            .          .           .       -0.02                .          .            .          .       -0.03       -0.17                    0.97       0.04
# Gastos del Gobierno Cent...          .            .          .           .       -0.13                .          .            .          .       -0.02        0.16                    0.96       0.03
# Exportaciones de Product...          .            .          .           .           .             0.15          .            .          .        0.03       -0.06                    0.95       0.08
# Exportaciones de Product...          .            .          .           .           .             0.21          .            .          .       -0.06       -0.04                    0.97       0.04
# Exportaciones de Product...          .            .          .           .           .             0.16          .            .          .        0.06        0.07                    0.98       0.02
# Exportaciones de Product...          .            .          .           .           .             0.33          .            .          .       -0.06       -0.05                    0.94       0.01
# Exportaciones de Product...          .            .          .           .           .             0.25          .            .          .        0.07       -0.07                    0.92       0.03
# Exportaciones de Product...          .            .          .           .           .             0.14          .            .          .        0.00        0.00                    0.95       0.07
# Exportaciones de Product...          .            .          .           .           .             0.30          .            .          .        0.01        0.01                    0.95       0.00
# Exportaciones de Product...          .            .          .           .           .             0.32          .            .          .       -0.06       -0.01                    0.94       0.01
# Exportaciones de Product...          .            .          .           .           .             0.30          .            .          .        0.00       -0.06                    0.98       0.01
# Exportaciones de Product...          .            .          .           .           .             0.17          .            .          .       -0.02        0.13                    0.97       0.01
# Exportaciones de Product...          .            .          .           .           .             0.27          .            .          .        0.02        0.02                    0.97       0.01
# Exportaciones de Product...          .            .          .           .           .             0.23          .            .          .       -0.03        0.05                    0.97       0.02
# Importaciones de Bienes ...          .            .          .           .           .             0.27          .            .          .        0.00        0.05                    0.95       0.01
#    Importaciones de Insumos          .            .          .           .           .             0.33          .            .          .       -0.02       -0.05                    0.94       0.00
# Importaciones de Bienes ...          .            .          .           .           .             0.22          .            .          .        0.07        0.04                    0.96       0.02
# Índice de Precios Nomina...          .            .          .           .           .             0.11          .            .          .        0.05       -0.02                    0.12       0.86
# Índice de Precios Nomina...          .            .          .           .           .             0.21          .            .          .       -0.02       -0.03                    0.32       0.58
# Tasa de Referencia de la...          .            .          .           .           .                .       0.25            .          .       -0.07        0.02                    0.98       0.01
#              Tasa de Encaje          .            .          .           .           .                .      -0.15            .          .       -0.16       -0.02                    0.68       0.29
# Tasa de los Créditos de ...          .            .          .           .           .                .       0.24            .          .       -0.08        0.01                    0.98       0.01
# Tasa de los Depósitos Ov...          .            .          .           .           .                .       0.23            .          .       -0.07        0.04                    0.98       0.01
# Rendimiento del Bono del...          .            .          .           .           .                .       0.11            .          .       -0.12        0.10                    0.89       0.06
# Reservas Internacionales...          .            .          .           .           .                .      -0.01            .          .        0.03       -0.01                   -0.09       0.97
# Dolarización del Crédito...          .            .          .           .           .                .       0.17            .          .        0.06        0.02                   -0.38       0.92
# Dolarización del Crédito...          .            .          .           .           .                .       0.01            .          .       -0.03       -0.01                    0.20       0.94
# Dolarización de la Liqui...          .            .          .           .           .                .       0.15            .          .        0.06        0.02                   -0.39       0.92
# Dolarización de la Liqui...          .            .          .           .           .                .      -0.19            .          .       -0.08        0.01                   -0.35       0.94
#         Valor del Fondo SPP          .            .          .           .           .                .       0.05            .          .        0.02       -0.04                    0.30       0.87
#         Tipo de cambio U.S.          .            .          .           .           .                .      -0.12            .          .       -0.03        0.04                    0.16       0.96
#         Tipo de cambio Euro          .            .          .           .           .                .      -0.04            .          .        0.04        0.02                    0.13       0.93
#         Tipo de cambio Yuan          .            .          .           .           .                .      -0.12            .          .        0.03        0.02                    0.25       0.83
# Emisión primaria por el ...          .            .          .           .           .                .      -0.04            .          .        0.09       -0.02                    0.34       0.68
#                  Circulante          .            .          .           .           .                .      -0.08            .          .        0.05       -0.02                   -0.14       0.88
#     Multiplicador monetario          .            .          .           .           .                .       0.07            .          .        0.00       -0.01                   -0.44       0.77
#     Prima de riesgo - EMBIG          .            .          .           .           .                .      -0.04            .          .       -0.08        0.15                    0.80       0.23
# Índice General de S&P/BV...          .            .          .           .           .                .          .        -0.26          .       -0.00        0.01                    0.09       0.80
#                   Cobre LME          .            .          .           .           .                .          .            .      -0.41        0.02        0.00                    0.05       0.29
#                     Oro LME          .            .          .           .           .                .          .            .      -0.29       -0.01       -0.04                    0.34       0.69
#             Plata H. Harman          .            .          .           .           .                .          .            .      -0.35       -0.00       -0.01                    0.17       0.59
#                    Zinc LME          .            .          .           .           .                .          .            .      -0.41       -0.02       -0.01                    0.20       0.34
#                  Estaño LME          .            .          .           .           .                .          .            .      -0.36        0.02        0.00                    0.47       0.41
#                   Plomo LME          .            .          .           .           .                .          .            .      -0.39       -0.04       -0.00                    0.00       0.51
#                Petróleo WTI          .            .          .           .           .                .          .            .      -0.23        0.00        0.03                    0.10       0.81
#                  Trigo EEUU          .            .          .           .           .                .          .            .      -0.11        0.02       -0.01                    0.15       0.92
#                   Maíz EEUU          .            .          .           .           .                .          .            .      -0.16        0.02        0.02                    0.25       0.85
#            Aceite Soya EEUU          .            .          .           .           .                .          .            .      -0.27        0.02        0.03                    0.24       0.66
# Harina de Pescado Hambur...          .            .          .           .           .                .          .            .       0.03        0.03        0.01                    0.46       0.74
# Producto EEUU: Manufactu...          .            .      -0.19           .           .                .          .            .          .        0.05        0.09                    0.19       0.87
# Effective Federal Funds ...          .            .          .           .           .                .       0.35            .          .        0.07       -0.05                    0.94       0.01
#       3-Month Treasury Bill          .            .          .           .           .                .       0.35            .          .        0.07       -0.04                    0.96       0.00
#       6-Month Treasury Bill          .            .          .           .           .                .       0.34            .          .        0.06       -0.04                    0.96       0.00
#        1-Year Treasury Rate          .            .          .           .           .                .       0.34            .          .        0.05       -0.03                    0.95       0.00
#        5-Year Treasury Rate          .            .          .           .           .                .       0.29            .          .       -0.02       -0.03                    0.90       0.02
#       10-Year Treasury Rate          .            .          .           .           .                .       0.26            .          .       -0.05       -0.02                    0.87       0.03
#             Indice de Dólar          .            .       0.03           .           .                .          .            .          .       -0.07       -0.00                    0.28       0.87
#                     S&P 500          .            .          .           .           .                .          .        -0.46          .        0.01       -0.01                    0.21       0.00
# Dow Jones Industrial Ave...          .            .          .           .           .                .          .        -0.46          .       -0.01       -0.01                    0.26       0.09
#            NASDAQ Composite          .            .          .           .           .                .          .        -0.41          .        0.03       -0.02                    0.23       0.12
#                    FTSE 100          .            .          .           .           .                .          .        -0.42          .       -0.04        0.02                    0.23       0.34
#                  Nikkei 225          .            .          .           .           .                .          .        -0.39          .        0.00        0.02                    0.19       0.44
#                  GDP Growth      -0.02            .          .           .           .                .          .            .          .       -0.01       -0.00                   -0.13       0.05
#                                                                                                                                                                                          Transition: Factor block 0
# ===========================================================================================================================================================================================================================================================================================================================================================================================================
#                   L1.Output L1.Labor Market L1.Juncture   L1.Prices L1.Government L1.Balance of Trade L1.Finance L1.Stock Market  L1.Quotes   L2.Output L2.Labor Market L2.Juncture  L2.Prices L2.Government L2.Balance of Trade  L2.Finance L2.Stock Market  L2.Quotes    error covariance     Output Labor Market    Juncture      Prices Government Balance of Trade    Finance Stock Market      Quotes
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#           Output       2.32           -0.01        0.04       -0.00         -0.25                0.27       0.10            0.01       0.05       -1.51           -0.01       -0.02       0.00          0.41               -0.24       -0.08            0.01      -0.02              Output       0.02         0.00        0.06       -0.04       0.01            -0.01      -0.01        -0.01       -0.02
#     Labor Market      -0.18            0.60        0.78       -0.01         -0.36               -0.82      -2.17            0.05       0.10       -0.18           -0.51       -0.62      -0.06          1.39                1.32        2.30            0.17       0.09        Labor Market       0.00         1.61        0.26       -0.48      -0.00             0.03       0.00        -0.07        0.06
#         Juncture       0.04           -0.02        0.84       -0.01         -0.97               -0.34      -0.85            0.09       0.11        1.13            0.05       -0.23       0.01         -0.42                0.18        0.90           -0.01       0.11            Juncture       0.06         0.26        0.90       -0.60       0.01            -0.04      -0.08         0.74        0.43
#           Prices       4.31           -0.08       -0.17       -0.05         -3.92                1.73      -1.37           -0.22       0.13       -4.57           -0.02        0.04      -0.11          4.97               -1.34        1.47           -0.28       0.44              Prices      -0.04        -0.48       -0.60        6.09      -0.02             0.08      -0.04        -0.74       -0.86
#       Government       0.34            0.00        0.04        0.00          1.55               -0.00       0.07            0.01       0.00       -0.47           -0.01       -0.02       0.00         -0.46                0.01       -0.07           -0.02       0.00          Government       0.01        -0.00        0.01       -0.02       0.01            -0.01       0.00        -0.01        0.02
# Balance of Trade      -0.40            0.00       -0.02        0.00          0.34                1.79       0.03            0.01       0.01        0.54            0.01        0.00       0.01         -0.50               -0.86       -0.05           -0.00      -0.04    Balance of Trade      -0.01         0.03       -0.04        0.08      -0.01             0.01       0.01        -0.08       -0.03
#          Finance       0.05           -0.00       -0.04       -0.01         -0.81               -0.71       1.31            0.03      -0.01       -0.00           -0.01        0.05      -0.02          0.80                0.77       -0.28            0.02       0.03             Finance      -0.01         0.00       -0.08       -0.04       0.00             0.01       0.05        -0.21       -0.02
#     Stock Market      -2.63            0.05        0.56        0.11          3.88                0.15       2.30            0.06      -0.11        1.96           -0.14       -0.46      -0.11         -3.05               -0.33       -2.59           -0.40       0.07        Stock Market      -0.01        -0.07        0.74       -0.74      -0.01            -0.08      -0.21         3.36        1.25
#           Quotes      -3.15            0.06        0.28       -0.06          1.44               -2.65      -0.12           -0.09      -0.04        3.07           -0.18       -0.34      -0.08         -1.44                2.32       -0.03           -0.18       0.19              Quotes      -0.02         0.06        0.43       -0.86       0.02            -0.03      -0.02         1.25        2.38
#                           Transition: Factor block 1
# ==============================================================================
#            L1.Global.1 L1.Global.2    error covariance    Global.1    Global.2
# ------------------------------------------------------------------------------
#   Global.1        1.00       -0.07            Global.1        0.29        0.29
#   Global.2        0.06        0.98            Global.2        0.29        0.61
# ==============================================================================
#
# Warnings:
# [1] Covariance matrix not calculated.
# """

# %% [markdown]
# ## Estimated Factors
# After the estimation process, we can recover the factors with their respective confidence bands:

# %%
# Declaration
factor_names = ['Global.1', 'Global.2']


# Compute 95% confidence intervals
mean = results.factors.smoothed[factor_names]
std   = pd.concat([results.factors.smoothed_cov.loc[name, name] for name in factor_names], axis=1)
crit  = norm.ppf(1 - 0.05 / 2)
lower = mean - crit * std
upper = mean + crit * std


with sns.color_palette('deep'):
    fig, ax = plt.subplots(figsize=(10, 4))
    mean.plot(ax=ax)
    
    for name in factor_names:
        ax.fill_between(mean.index, lower[name], upper[name], alpha=0.3)

    plt.title('Estimated factors: smoothed estimates and 95% confidence intervals', fontsize=13)
    plt.legend(fontsize=10, edgecolor="white")
    
    fig.tight_layout()
    plt.plot()

# %% [markdown]
# ## $R^2$ of individual factors
# We can also review which are the most relevant indicators in each group/factor:

# %%
with sns.color_palette('deep'):
    fig = results.plot_coefficients_of_determination(method='individual', figsize=(10, 14))
    fig.suptitle(r'$R^2$ - regression on individual factors', fontsize=13, y=1)
    fig.tight_layout()

# %% [markdown]
# ## Forecasting
# Then, with the latest monthly data, the nowcasting models allow us to forecast with all the information possible:

# %%
first_period    = str(df_q.index[0])
last_period     = str(df_q.index[-1])
forecast_period = '2024Q4' # To define

print(f'Last oficial value on: {last_period}, and we estimated until {forecast_period}')
# Out:
# Last oficial value on: 2023Q2, and we estimated until 2024Q4

# %%
# Monthly GDP Growth estimated to Quarterly
forecast = results.forecast(forecast_period)['GDP Growth'].resample('Q').last()
h        = len(forecast)


# New GDP DataFrame ========================================================================
new_periods = pd.period_range(start=first_period, end=forecast_period, freq='Q')
df_q_f      = pd.DataFrame(index=new_periods, columns=['Real GDP', 'GDP Growth'])

# GDP Growth
df_q_f.loc[:last_period, 'Real GDP']   = df_q['Real GDP']
df_q_f.loc[:last_period, 'GDP Growth'] = df_q['GDP Growth']
df_q_f.loc[-h:, 'GDP Growth'] = forecast

# GDP 2023Q2 -> Only for this quarter
# df_q_f.loc['2023Q2', 'GDP Growth'] = float(
#     results.predict()[results.predict().index=='2023-06']['GDP Growth']
# )

# Real GDP
last_real_gdp = df_q_f.loc[df_q_f['Real GDP'].last_valid_index(), 'Real GDP']

for i in range(len(df_q_f)):
    if df_q_f.index[i] >= pd.Period(last_period):
        previous_real_gdp = df_q_f.loc[df_q_f.index[i-4], 'Real GDP']
        gdp_growth = df_q_f.loc[df_q_f.index[i], 'GDP Growth']
        df_q_f.loc[df_q_f.index[i], 'Real GDP'] = previous_real_gdp * (1 + gdp_growth / 100)

df_q_f['Real GDP'] = df_q_f['Real GDP'].fillna(method='ffill')


# Check
print(f'\nReal GDP and Real GDP Growth\n(oficial until {last_period} and forecast):\n')
df_q_f.tail(12)
# Out:
# Real GDP and Real GDP Growth
# (oficial until 2023Q2 and forecast):
#              Real GDP GDP Growth
# 2022Q1  133284.727000   3.913422
# 2022Q2  140994.752000   3.370007
# 2022Q3  143375.542000   1.956069
# 2022Q4  148859.433000   1.661968
# 2023Q1  132740.399281  -0.408395
# 2023Q2  140295.871288  -0.495679
# 2023Q3  145522.435531   1.497392
# 2023Q4  153180.838341   2.903011
# 2024Q1  137618.452847   3.674882
# 2024Q2  145713.748533   3.861751
# 2024Q3  150936.615507   3.720512
# 2024Q4  158786.590099   3.659565

# %%
print(f'\nAnnual forecast:\n')
pd.DataFrame(
    {
        'Real GDP': np.round( df_q_f['Real GDP'].resample('Y').sum(), 0),
        'GDP Growth': np.round( df_q_f['Real GDP'].resample('Y').sum().pct_change() * 100, 2)
    }
).loc['2023':]
# Out:
# Annual forecast:
#       Real GDP  GDP Growth
# 2023  571740.0        0.92
# 2024  593055.0        3.73

# %%
xmin = '2018Q1'
xmax = '2024Q4'


with sns.color_palette('deep'):
    fig = plt.plot(figsize=(8, 5))

    # Plot GDP growth data: historic and forecast
    df_q_f.loc[xmin:xmax, 'GDP Growth'].plot()
    plt.title('Real Gross Domestic Product\n(annualized growth rate)')
    plt.axhline(y=0, color='black', linestyle='--')
   
    # Fill
    ylim = plt.ylim()
    plt.fill_between(df_q_f.loc[last_period:].index, ylim[0], ylim[1], alpha=0.15, color='C0')
    plt.annotate(r' Forecast $\rightarrow$', (last_period, ylim[0] + 0.1 * ylim[1]))
    plt.ylim(ylim[0], ylim[1])

    plt.tight_layout()
    plt.show()


print('GDP Growth / Forecast: ')
print(df_q_f['GDP Growth'].tail(h+2))
# Out:
# GDP Growth / Forecast:
# 2023Q1   -0.408395
# 2023Q2   -0.495679
# 2023Q3    1.497392
# 2023Q4    2.903011
# 2024Q1    3.674882
# 2024Q2    3.861751
# 2024Q3    3.720512
# 2024Q4    3.659565
# Freq: Q-DEC, Name: GDP Growth, dtype: object

# %%
xmin = '2015Q1'
xmax = '2024Q4'


with sns.color_palette('deep'):
    fig = plt.plot(figsize=(8, 5))

    # Plot GDP growth data: historic and forecast
    df_q_f.loc[xmin:xmax, 'Real GDP'].plot()
    plt.title('Real Gross Domestic Product\n(S/ 2007 Millions)')
   
    # Fill
    ylim = plt.ylim()
    plt.fill_between(df_q_f.loc[last_period:].index, ylim[0], ylim[1], alpha=0.15, color='C0')
    plt.annotate(r' Forecast $\rightarrow$', (last_period, ylim[0] + 0.1 * ylim[1]))
    plt.ylim(ylim[0], ylim[1])

    plt.tight_layout()
    plt.show()


print('Real GDP / Forecast: ')
print(df_q_f['Real GDP'].tail(h+2))
# Out:
# Real GDP / Forecast:
# 2023Q1    132740.399281
# 2023Q2    140295.871288
# 2023Q3    145522.435531
# 2023Q4    153180.838341
# 2024Q1    137618.452847
# 2024Q2    145713.748533
# 2024Q3    150936.615507
# 2024Q4    158786.590099
# Freq: Q-DEC, Name: Real GDP, dtype: float64

# %% [markdown]
# ## Updated forecast across the months
# Since past datasets has been recorded, it is possible to analyze how forecasts of particular quarters have changed as more information is obtained:

# %%
vintage_results = {}
quarter_to_predict = '2023Q4'


for date in list(dta.keys()):
    
    # Get updated data for the vintage
    updated_endog_m = dta[date].loc[first_period:, :]
    updated_endog_q = dta_gdp[date].loc[first_period:, ['GDP Growth']]

    # Get updated results
    vintage_results[date] = results.apply(
        updated_endog_m,
        endog_quarterly=updated_endog_q
    )

# Saving results
forecasts = {
    vintage: res.forecast(forecast_period)['GDP Growth'].resample('Q').last()\
        .loc[quarter_to_predict] for vintage, res in vintage_results.items()
}

forecasts = pd.Series(
    list(forecasts.values()),
    index=pd.PeriodIndex(forecasts.keys(), freq='M')
)
    
# Print our forecast of the Real GDP Growth across all dates
for vintage, value in forecasts.items():
    print(f'{vintage} forecast of the Real GDP growth in {quarter_to_predict}:'
          f' {value:.2f}%'
    )
# Out:
# 2023-05 forecast of the Real GDP growth in 2023Q4: 3.27%
# 2023-06 forecast of the Real GDP growth in 2023Q4: 2.23%
# 2023-07 forecast of the Real GDP growth in 2023Q4: 2.92%
# 2023-08 forecast of the Real GDP growth in 2023Q4: 2.91%
